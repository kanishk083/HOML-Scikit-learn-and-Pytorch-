# %%
import numpy as np
import pandas as pd
from sklearn.datasets import make_classification

# %%
X,y = make_classification(n_features=5,n_redundant=0, n_informative=5, n_clusters_per_class=1)

# %%
df = pd.DataFrame(X,columns=['col1','col2','col3','col4','col5'])
df['target']=y
print(df.shape)
df.head()
# Out:
# (100, 6)
#        col1      col2      col3      col4      col5  target
# 0  1.273368  1.746366 -0.300801  2.699444 -2.653950       0
# 1 -1.557834 -1.295155  0.309536  2.900588 -1.270413       0
# 2 -2.300959 -2.576657 -2.240810 -1.073218 -0.740139       1
# 3 -2.503602 -1.839537 -0.575705  1.991180 -0.866966       0
# 4  0.738527  1.134425  0.530904 -0.561535 -0.418421       1

# %%
#Row sampling function

def sample_row(df,percent):
  return df.sample(int(percent*df.shape[0]),replace=True)

# %%
#Column Sampling function
def sample_col(df,percent):
  cols = random.sample(df,columns.tolist()[:-1],int(percent*df.shape[1]-1))
  df_new =df[cols]
  df_new['target'] = df_new['target']
  return df_new

# %%
# Combined Sampling
def combined(df,row_percent,col_percent):
  new_df = sample_row(df,row_percent)
  return sample_col(new_df,col_percent)

# %% [markdown]
# Row-sampling

# %%
df1 = sample_row(df,0.2)

# %%
sample_row(df,0.2)
# Out:
#         col1      col2      col3      col4      col5  target
# 68  2.446421 -1.000307 -1.403265 -0.214083 -1.493876       0
# 96 -2.815534 -3.075543 -2.271431 -1.581562 -0.744785       1
# 4   0.738527  1.134425  0.530904 -0.561535 -0.418421       1
# 21  1.461942  1.418023 -0.676804  1.052088 -1.613699       0
# 58 -0.512970 -0.537354 -0.523609 -1.199176 -0.340123       1
# 62 -0.860451 -2.972111 -0.860897  2.094507  0.071144       0
# 22 -3.670564 -5.268995 -3.331579 -0.015248 -1.924411       1
# 88 -3.372255 -2.748463 -1.355777 -0.157085 -2.589264       1
# 32 -1.080020 -0.812970 -0.904439 -0.810631 -1.506886       1
# 40 -1.553622  0.464472 -0.511790 -1.664140 -2.062518       1
# 44 -3.023997 -3.186117 -1.637084  0.562492 -2.921382       1
# 65  0.976187 -1.784217 -0.889696  0.635951  0.017529       0
# 64 -2.489163 -3.513079 -1.669801 -0.203523 -1.251209       1
# 41  1.190759 -2.388425 -1.194386  0.494826 -0.842879       0
# ...

# %%
df2= sample_row(df,0.2)

# %%
df3 = sample_row(df,0.2)

# %%
from sklearn.tree import DecisionTreeClassifier
clf1=DecisionTreeClassifier()
clf2=DecisionTreeClassifier()
clf3=DecisionTreeClassifier()

# %%
clf1.fit(df1.iloc[:,0:5],df1.iloc[:,-1])
clf2.fit(df2.iloc[:,0:5],df2.iloc[:,-1])
clf3.fit(df3.iloc[:,0:5],df3.iloc[:,-1])
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.tree import plot_tree

# %%
plot_tree(clf1)
# Out:
# [Text(0.5, 0.9, 'x[3] <= -1.029\ngini = 0.42\nsamples = 20\nvalue = [14, 6]'),
#  Text(0.3333333333333333, 0.7, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.41666666666666663, 0.8, 'True  '),
#  Text(0.6666666666666666, 0.7, 'x[2] <= 0.656\ngini = 0.219\nsamples = 16\nvalue = [14, 2]'),
#  Text(0.5833333333333333, 0.8, '  False'),
#  Text(0.5, 0.5, 'x[0] <= -0.551\ngini = 0.124\nsamples = 15\nvalue = [14, 1]'),
#  Text(0.3333333333333333, 0.3, 'x[4] <= -1.612\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.16666666666666666, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5, 0.1, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.6666666666666666, 0.3, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.8333333333333334, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]')]

# %%
plot_tree(clf2)
# Out:
# [Text(0.4, 0.875, 'x[3] <= -0.247\ngini = 0.495\nsamples = 20\nvalue = [9, 11]'),
#  Text(0.2, 0.625, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.30000000000000004, 0.75, 'True  '),
#  Text(0.6, 0.625, 'x[0] <= -0.487\ngini = 0.298\nsamples = 11\nvalue = [9, 2]'),
#  Text(0.5, 0.75, '  False'),
#  Text(0.4, 0.375, 'x[3] <= 1.872\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.2, 0.125, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8, 0.375, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]')]

# %%
plot_tree(clf3)
# Out:
# [Text(0.6, 0.875, 'x[3] <= 0.243\ngini = 0.42\nsamples = 20\nvalue = [14, 6]'),
#  Text(0.4, 0.625, 'x[0] <= 0.812\ngini = 0.245\nsamples = 7\nvalue = [1, 6]'),
#  Text(0.5, 0.75, 'True  '),
#  Text(0.2, 0.375, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.6, 0.375, 'x[2] <= -0.892\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.4, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8, 0.625, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(0.7, 0.75, '  False')]

# %%
clf1.predict(np.array([-1.557834,	-1.295155,	0.309536,	2.900588,	-1.270413]).reshape(1,5))
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0])

# %%
clf2.predict(np.array([-1.557834,	-1.295155,	0.309536,	2.900588,	-1.270413]).reshape(1,5))
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0])

# %%
clf3.predict(np.array([-1.557834,	-1.295155,	0.309536,	2.900588,	-1.270413]).reshape(1,5))
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0])
